# %%
from IPython.display import IFrame, HTML, SVG, display, Image
import IPython.display as ipd

# %% [markdown]
# # Birdclef 2021
#
# ## Birdcall Identification
#
# ![image.png](attachment:b69d31c8-3c0b-4f22-b988-46f3f92ed65b.png)

# %%
ipd.Audio('sample_audio/acafly/XC109605.ogg')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Motivation
# <br>
#
#
# ### Technical
# - Working with "complex" mixed data-sources including audio
# - "Real world" problem
# -
#
# ### Ethical
# - Contributing to wild-life monitoring --> preservation

# %% [markdown]
# # Data
#
# XXXX Audio files of length XXXX containing XXXX different species

# %%
IFrame('figures/world_map_density.html', width=850, height=550)
# Out:
#         <iframe
#             width="850"
#             height="550"
#             src="figures/world_map_density.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
IFrame('figures/world_map_species.html', width=900, height=500)
# Out:
#         <iframe
#             width="900"
#             height="500"
#             src="figures/world_map_species.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Procedure

# %%
Image(url='figures/Flowchart.svg', width=550)
# Out:
# <img src="figures/Flowchart.svg" width="550"/>

# %% [markdown]
# # Feature Engineering
#
# - Noise

# %% [markdown]
# # Audio Augmentation
#
# - Shifting

# %% [markdown]
# # Spectograms

# %% [markdown]
# # Numeric features
#
# - Contextual dimensions
#     - BPM
#     - Harmonics

# %% [markdown]
# # ML Models - CNN

# %% [markdown]
# # ML Models - CNN

# %% [markdown]
# # ML Models - MLP

# %% [markdown]
# # ML Models - LSTM

# %% [markdown]
# # ML Models - Mixed

# %% [markdown]
# # ML Models - Deep CNNs

# %% [markdown]
# # ML Models - GAN

# %% [markdown]
# # Summing up

# %% [markdown]
# # References

# %% [markdown]
# # Appendix
